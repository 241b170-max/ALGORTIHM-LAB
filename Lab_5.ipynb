# %% [markdown]
# <a href="https://colab.research.google.com/github/241b170-max/ALGORTIHM-LAB/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.

# %%
import time
import matplotlib.pyplot as plt
import random

def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i+1, n):
            if arr[j] < arr[min_index]:
                min_index = j

        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

n = int(input("Enter number of elements: "))
numbers = []
for i in range(n):
    num = int(input(f"Enter element {i+1}: "))
    numbers.append(num)

print("Original List:", numbers)

start_time = time.time()
sorted_list = selection_sort(numbers)
end_time = time.time()

print("Sorted List:", sorted_list)
print("Running Time:", end_time - start_time, "seconds")

sizes = [10, 50, 100, 200, 300, 400, 500]
times = []

for size in sizes:
    test_list = random.sample(range(1, size*10), size)  # random list
    start = time.time()
    selection_sort(test_list)
    end = time.time()
    times.append(end - start)


plt.plot(sizes, times, marker='o')
plt.xlabel("Input Size (n)")
plt.ylabel("Running Time (seconds)")
plt.title("Selection Sort Runtime Analysis")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 5
# Enter element 1: 3
# Enter element 2: 2
# Enter element 3: 4
# Enter element 4: 1
# Enter element 5: 5
# Original List: [3, 2, 4, 1, 5]
# Sorted List: [1, 2, 3, 4, 5]
# Running Time: 7.009506225585938e-05 seconds

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.

# %%
import time
import matplotlib.pyplot as plt
import random

def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0


        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1


        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1

    return arr

n = int(input("Enter number of elements: "))
numbers = []
for i in range(n):
    num = int(input(f"Enter element {i+1}: "))
    numbers.append(num)

print("Original List:", numbers)

start_time = time.time()
sorted_list = merge_sort(numbers)
end_time = time.time()

print("Sorted List:", sorted_list)
print("Running Time:", end_time - start_time, "seconds")


sizes = [10, 50, 100, 200, 300, 400, 500, 1000, 2000]
times = []

for size in sizes:
    test_list = random.sample(range(1, size*10), size)  # random list
    start = time.time()
    merge_sort(test_list)
    end = time.time()
    times.append(end - start)


plt.plot(sizes, times, marker='o', color='blue')
plt.xlabel("Input Size (n)")
plt.ylabel("Running Time (seconds)")
plt.title("Merge Sort Runtime Analysis")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 5
# Enter element 1: 2
# Enter element 2: 1
# Enter element 3: 3
# Enter element 4: 5
# Enter element 5: 4
# Original List: [2, 1, 3, 5, 4]
# Sorted List: [1, 2, 3, 4, 5]
# Running Time: 0.00015592575073242188 seconds

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.

# %%
import time
import matplotlib.pyplot as plt
import random


def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[len(arr) // 2]
        left = [x for x in arr if x < pivot]
        middle = [x for x in arr if x == pivot]
        right = [x for x in arr if x > pivot]
        return quick_sort(left) + middle + quick_sort(right)

n = int(input("Enter number of elements: "))
numbers = []
for i in range(n):
    num = int(input(f"Enter element {i+1}: "))
    numbers.append(num)

print("Original List:", numbers)

start_time = time.time()
sorted_list = quick_sort(numbers)
end_time = time.time()

print("Sorted List:", sorted_list)
print("Running Time:", end_time - start_time, "seconds")


sizes = [10, 50, 100, 200, 300, 400, 500, 1000, 2000, 5000]
times = []

for size in sizes:
    test_list = random.sample(range(1, size*10), size)
    start = time.time()
    quick_sort(test_list)
    end = time.time()
    times.append(end - start)


plt.plot(sizes, times, marker='o', color='red')
plt.xlabel("Input Size (n)")
plt.ylabel("Running Time (seconds)")
plt.title("Quick Sort Runtime Analysis")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 5
# Enter element 1: 4
# Enter element 2: 3
# Enter element 3: 5
# Enter element 4: 2
# Enter element 5: 1
# Original List: [4, 3, 5, 2, 1]
# Sorted List: [1, 2, 3, 4, 5]
# Running Time: 6.818771362304688e-05 seconds

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
sizes = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
trials = 5

# %%
# Creating a random value (uniform)
import random

# Random float between 1 and 10
value = random.uniform(1, 10)
print("Random uniform value:", value)
# Out:
# Random uniform value: 3.3867086727884805

# %%
import numpy as np

# Single random value between 0 and 1
val = np.random.uniform(0, 1)
print("Single random value:", val)

# Generate 5 random values between 10 and 20
arr = np.random.uniform(10, 20, 5)
print("Array of random values:", arr)
# Out:
# Single random value: 0.3654307658669005
# Array of random values: [17.11713293 18.19004297 19.69609471 12.83849241 19.49387285]

# %%
# Plotting results
import matplotlib.pyplot as plt

# Example experiment variables
input_sizes = [10, 50, 100, 200, 500, 1000, 2000, 5000]   # independent variable
quick_times = [0.0001, 0.0002, 0.0005, 0.001, 0.003, 0.007, 0.015, 0.04]  # dependent variable (sample data)
merge_times = [0.0001, 0.00015, 0.0003, 0.0007, 0.002, 0.004, 0.009, 0.02]
selection_times = [0.0001, 0.0005, 0.002, 0.008, 0.03, 0.12, 0.5, 2.0]

# Plotting results
plt.plot(input_sizes, quick_times, marker='o', color='red', label="Quick Sort")
plt.plot(input_sizes, merge_times, marker='s', color='blue', label="Merge Sort")
plt.plot(input_sizes, selection_times, marker='^', color='green', label="Selection Sort")

plt.xlabel("Input Size (n)")
plt.ylabel("Running Time (seconds)")
plt.title("Sorting Algorithms Runtime Comparison")
plt.legend()
plt.grid(True)
plt.show()
